# %% [markdown]
# This notebook creates and trains a simple RNN network for classifiyng podcast using the textual description.

# %%
import tensorflow as tf
import pandas as pd
from tensorflow import keras
from keras import models, layers
from keras import preprocessing
from keras_preprocessing.image import ImageDataGenerator
import numpy as np
from sklearn.model_selection import train_test_split
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer 
from nltk.tokenize import word_tokenize 
from sklearn.preprocessing import MultiLabelBinarizer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/podcast/appledataset/podcast_final.csv')

# %%
df.head(6)
# Out:
#                                                 Name  \
# 0                 Firearms Radio Network (All Shows)
# 1  Clear and Present Danger - A history of free s...
# 2                                2 Idiots and a List
# 3                                          Forever35
# 4                                          DarbyCast
# 5                             Inside Running Podcast
#
#                                              Artwork      Primary Genre  \
# 0  https://is1-ssl.mzstatic.com/image/thumb/Podca...             Nature
# 1  https://is4-ssl.mzstatic.com/image/thumb/Podca...  Society & Culture
# 2  https://is4-ssl.mzstatic.com/image/thumb/Podca...              Music
# 3  https://is5-ssl.mzstatic.com/image/thumb/Podca...   Fashion & Beauty
# 4  https://is2-ssl.mzstatic.com/image/thumb/Podca...            Fiction
# 5  https://is2-ssl.mzstatic.com/image/thumb/Podca...             Sports
#
#                                          Description  \
# 0                                        Master Feed
# 1  Why have kings, emperors, and governments kill...
# 2  Welcome to “2 Idiots and a List”, the podcast ...
# 3  Which night creams will make you look well-res...
# 4  Neither the Darbyshire book series, nor this p...
# 5  A weekly podcast by 3 fast runners, for all ru...
#
#                                            filepaths
# 0  /content/drive/MyDrive/Colab_Notebooks/podcast...
# 1  /content/drive/MyDrive/Colab_Notebooks/podcast...
# 2  /content/drive/MyDrive/Colab_Notebooks/podcast...
# 3  /content/drive/MyDrive/Colab_Notebooks/podcast...
# 4  /content/drive/MyDrive/Colab_Notebooks/podcast...
# 5  /content/drive/MyDrive/Colab_Notebooks/podcast...

# %%
from sklearn.utils import shuffle
df = shuffle(df, random_state = 42)
df['Primary Genre'] = [[el]for el in df['Primary Genre'].tolist()]
df_train = df[:28279]
df_test = df[28279:]
df_train, df_valid = train_test_split(df_train, shuffle = True, train_size=0.8)

# %% [markdown]
# Textual data was pre-processed in order to normalize it. Each description was tokenized, lowered, removed stopwords and lemmatize. This allow to extract the semantic meaning of each word getting rid of the noise.

# %%
stopw = stopwords.words('english')
tokenizer = nltk.RegexpTokenizer(r"\w+")

lemmatizer = WordNetLemmatizer()
def clean_text(text):
  text = text.lower().strip()
  text = tokenizer.tokenize(text)
  clean_text = [w for w in text if w.lower() not in stopw]
  clean_text = " ".join([lemmatizer.lemmatize(w) for w in clean_text])
  return clean_text

# %%
df_train['Description'] = [clean_text(el) for el in df_train['Description'].tolist()]
df_valid['Description'] = [clean_text(el) for el in df_valid['Description'].tolist()]
df_test['Description'] = [clean_text(el) for el in df_test['Description'].tolist()]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
mlb = MultiLabelBinarizer()
mlb.fit(df['Primary Genre'].tolist())
mlb.classes_
# Out:
# array(['After Shows', 'Animation & Manga', 'Arts', 'Books', 'Business',
#        'Comedy', 'Design', 'Documentary', 'Education', 'Fashion & Beauty',
#        'Fiction', 'Food', 'Games', 'Health', 'Hobbies', 'Interviews',
#        'Kids & Family', 'Music', 'Nature', 'News', 'Non-Profit',
#        'Personal', 'Pets & Animals', 'Places & Travel', 'Politics',
#        'Religion', 'Science', 'Sexuality', 'Society & Culture', 'Sports',
#        'Stand-Up', 'TV & Film', 'Technology', 'True Crime', 'Vehicles'],
#       dtype=object)

# %%
genres = df['Primary Genre'].tolist()
transformed_labels = mlb.transform(genres)
transformed_labels.shape
# Out:
# (29279, 35)

# %%
train_labels = mlb.transform(df_train['Primary Genre'].tolist())
train_labels.shape

val_labels = mlb.transform(df_valid['Primary Genre'].tolist())
val_labels.shape

test_labels = mlb.transform(df_test['Primary Genre'].tolist())
test_labels.shape
# Out:
# (1000, 35)

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Model, load_model
from keras.layers import Embedding, LSTM, Dropout, Dense, Input, Bidirectional, Flatten, Conv2D, MaxPooling2D, concatenate, Conv1D, MaxPooling1D
import keras.backend as K
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping

# %% [markdown]
# The corpus was prepared for training using the standard methods of keras. It is necessary to obtain the number of unique tokens, creating a dictionary that can be used to map each token with a numerical ID. Moreover, it is necessary to have the maximum length of a sample.

# %%
MAX_NB_WORDS = 50000
MAX_SEQUENCE_LENGTH = df['Description'].map(len).max()
EMBEDDING_DIM = 300
tokenizer = Tokenizer(num_words=MAX_NB_WORDS, lower=True)
tokenizer.fit_on_texts(df['Description'].values)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
print('Max len:', MAX_SEQUENCE_LENGTH)
# Out:
# Found 96388 unique tokens.
# Max len: 3979

# %%
X_text_train = tokenizer.texts_to_sequences(df_train['Description'].values)
X_text_train = pad_sequences(X_text_train, maxlen=MAX_SEQUENCE_LENGTH) #include padding to make each instance of the same length
print('Shape of train tensor:', X_text_train.shape)
# Out:
# Shape of train tensor: (22623, 3979)

# %%
X_text_test = tokenizer.texts_to_sequences(df_test['Description'].values)
X_text_test = pad_sequences(X_text_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of train tensor:', X_text_test.shape)
# Out:
# Shape of train tensor: (1000, 3979)

# %%
X_text_val = tokenizer.texts_to_sequences(df_valid['Description'].values)
X_text_val = pad_sequences(X_text_val, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of train tensor:', X_text_val.shape)
# Out:
# Shape of train tensor: (5656, 3979)

# %% [markdown]
# A simple RNN network to process text was made using GRU layers instead of regular RNN ones.

# %%
model = keras.models.Sequential([
keras.layers.Embedding(len(word_index), EMBEDDING_DIM, input_length=MAX_SEQUENCE_LENGTH, input_shape=[None], trainable=False),
keras.layers.GRU(128), return_sequences=True)
keras.layers.Dropout(0.3),
keras.layers.GRU(128),
keras.layers.Dropout(0.5),
keras.layers.Dense(35, activation="softmax")
], name='my_RNN')
model.summary()

# %%
model.compile(loss="categorical_crossentropy", optimizer=keras.optimizers.Adam(),
metrics=["accuracy", tf.keras.metrics.TopKCategoricalAccuracy(5)])

# %%
CSV_log = tf.keras.callbacks.CSVLogger('/content/drive/MyDrive/Colab_Notebooks/podcast/RNN_log.csv', separator=",", append=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=7,
restore_best_weights=True, monitor='val_loss')

model_checkpoint = keras.callbacks.ModelCheckpoint('/content/drive/MyDrive/Colab_Notebooks/podcast/my_RNN_checkpoint.h5', monitor='val_loss', save_best_only = True, verbose = 1)
history = model.fit(X_text_train, train_labels, validation_data=(X_text_val, val_labels), epochs=50, callbacks=[early_stopping_cb, model_checkpoint, CSV_log])
# Out:
# Epoch 1/50
# 707/707 [==============================] - ETA: 0s - loss: 3.2785 - accuracy: 0.1214 - top_k_categorical_accuracy: 0.3789
# Epoch 1: val_loss improved from inf to 3.21423, saving model to /content/drive/MyDrive/Colab_Notebooks/podcast/my_RNN_1layer:checkpoint.h5
# 707/707 [==============================] - 388s 541ms/step - loss: 3.2785 - accuracy: 0.1214 - top_k_categorical_accuracy: 0.3789 - val_loss: 3.2142 - val_accuracy: 0.1427 - val_top_k_categorical_accuracy: 0.3998
# Epoch 2/50
# 707/707 [==============================] - ETA: 0s - loss: 3.1012 - accuracy: 0.1748 - top_k_categorical_accuracy: 0.4318
# Epoch 2: val_loss improved from 3.21423 to 2.98522, saving model to /content/drive/MyDrive/Colab_Notebooks/podcast/my_RNN_1layer:checkpoint.h5
# 707/707 [==============================] - 383s 541ms/step - loss: 3.1012 - accuracy: 0.1748 - top_k_categorical_accuracy: 0.4318 - val_loss: 2.9852 - val_accuracy: 0.2049 - val_top_k_categorical_accuracy: 0.4595
# Epoch 3/50
# 707/707 [==============================] - ETA: 0s - loss: 2.8679 - accuracy: 0.2375 - top_k_categorical_accuracy: 0.4975
# Epoch 3: val_loss improved from 2.98522 to 2.78358, saving model to /content/drive/MyDrive/Colab_Notebooks/podcast/my_RNN_1layer:checkpoint.h5
# 707/707 [==============================] - 383s 542ms/step - loss: 2.8679 - accuracy: 0.2375 - top_k_categorical_accuracy: 0.4975 - val_loss: 2.7836 - val_accuracy: 0.2641 - val_top_k_categorical_accuracy: 0.5134
# Epoch 4/50
# 707/707 [==============================] - ETA: 0s - loss: 2.6613 - accuracy: 0.2930 - top_k_categorical_accuracy: 0.5608
# Epoch 4: val_loss improved from 2.78358 to 2.61388, saving model to /content/drive/MyDrive/Colab_Notebooks/podcast/my_RNN_1layer:checkpoint.h5
# 707/707 [==============================] - 390s 552ms/step - loss: 2.6613 - accuracy: 0.2930 - top_k_categorical_accuracy: 0.5608 - val_loss: 2.6139 - val_accuracy: 0.3030 - val_top_k_categorical_accuracy: 0.5695
# Epoch 5/50
# 707/707 [==============================] - ETA: 0s - loss: 2.5149 - accuracy: 0.3270 - top_k_categorical_accuracy: 0.6041
# Epoch 5: val_loss improved from 2.61388 to 2.51620, saving model to /content/drive/MyDrive/Colab_Notebooks/podcast/my_RNN_1layer:checkpoint.h5
# 707/707 [==============================] - 384s 544ms/step - loss: 2.5149 - accuracy: 0.3270 - top_k_categorical_accuracy: 0.6041 - val_loss: 2.5162 - val_accuracy: 0.3292 - val_top_k_categorical_accuracy: 0.5997
# Epoch 6/50
# 707/707 [==============================] - ETA: 0s - loss: 2.3849 - accuracy: 0.3574 - top_k_categorical_accuracy: 0.6436
# Epoch 6: val_loss improved from 2.51620 to 2.42910, saving model to /content/drive/MyDrive/Colab_Notebooks/podcast/my_RNN_1layer:checkpoint.h5
# 707/707 [==============================] - 384s 543ms/step - loss: 2.3849 - accuracy: 0.3574 - top_k_categorical_accuracy: 0.6436 - val_loss: 2.4291 - val_accuracy: 0.3460 - val_top_k_categorical_accuracy: 0.6271
# Epoch 7/50
# 707/707 [==============================] - ETA: 0s - loss: 2.2741 - accuracy: 0.3859 - top_k_categorical_accuracy: 0.6700
# Epoch 7: val_loss improved from 2.42910 to 2.37610, saving model to /content/drive/MyDrive/Colab_Notebooks/podcast/my_RNN_1layer:checkpoint.h5
# 707/707 [==============================] - 382s 540ms/step - loss: 2.2741 - accuracy: 0.3859 - top_k_categorical_accuracy: 0.6700 - val_loss: 2.3761 - val_accuracy: 0.3670 - val_top_k_categorical_accuracy: 0.6399
# Epoch 8/50
# 707/707 [==============================] - ETA: 0s - loss: 2.1785 - accuracy: 0.4081 - top_k_categorical_accuracy: 0.6942
# Epoch 8: val_loss improved from 2.37610 to 2.30948, saving model to /content/drive/MyDrive/Colab_Notebooks/podcast/my_RNN_1layer:checkpoint.h5
# 707/707 [==============================] - 382s 540ms/step - loss: 2.1785 - accuracy: 0.4081 - top_k_categorical_accuracy: 0.6942 - val_loss: 2.3095 - val_accuracy: 0.3856 - val_top_k_categorical_accuracy: 0.6563
# Epoch 9/50
# 707/707 [==============================] - ETA: 0s - loss: 2.0931 - accuracy: 0.4282 - top_k_categorical_accuracy: 0.7170
# Epoch 9: val_loss improved from 2.30948 to 2.27423, saving model to /content/drive/MyDrive/Colab_Notebooks/podcast/my_RNN_1layer:checkpoint.h5
# 707/707 [==============================] - 382s 541ms/step - loss: 2.0931 - accuracy: 0.4282 - top_k_categorical_accuracy: 0.7170 - val_loss: 2.2742 - val_accuracy: 0.3990 - val_top_k_categorical_accuracy: 0.6720
# Epoch 10/50
# 707/707 [==============================] - ETA: 0s - loss: 2.0199 - accuracy: 0.4483 - top_k_categorical_accuracy: 0.7339
# Epoch 10: val_loss improved from 2.27423 to 2.24494, saving model to /content/drive/MyDrive/Colab_Notebooks/podcast/my_RNN_1layer:checkpoint.h5
# 707/707 [==============================] - 383s 542ms/step - loss: 2.0199 - accuracy: 0.4483 - top_k_categorical_accuracy: 0.7339 - val_loss: 2.2449 - val_accuracy: 0.4038 - val_top_k_categorical_accuracy: 0.6782
# Epoch 11/50
# 707/707 [==============================] - ETA: 0s - loss: 1.9385 - accuracy: 0.4674 - top_k_categorical_accuracy: 0.7519
# Epoch 11: val_loss improved from 2.24494 to 2.21239, saving model to /content/drive/MyDrive/Colab_Notebooks/podcast/my_RNN_1layer:checkpoint.h5
# 707/707 [==============================] - 383s 542ms/step - loss: 1.9385 - accuracy: 0.4674 - top_k_categorical_accuracy: 0.7519 - val_loss: 2.2124 - val_accuracy: 0.4162 - val_top_k_categorical_accuracy: 0.6927
# Epoch 12/50
# 707/707 [==============================] - ETA: 0s - loss: 1.8768 - accuracy: 0.4833 - top_k_categorical_accuracy: 0.7659
# Epoch 12: val_loss improved from 2.21239 to 2.19421, saving model to /content/drive/MyDrive/Colab_Notebooks/podcast/my_RNN_1layer:checkpoint.h5
# 707/707 [==============================] - 383s 542ms/step - loss: 1.8768 - accuracy: 0.4833 - top_k_categorical_accuracy: 0.7659 - val_loss: 2.1942 - val_accuracy: 0.4227 - val_top_k_categorical_accuracy: 0.6996
# Epoch 13/50
# 707/707 [==============================] - ETA: 0s - loss: 1.8078 - accuracy: 0.5002 - top_k_categorical_accuracy: 0.7803
# Epoch 13: val_loss did not improve from 2.19421
# 707/707 [==============================] - 381s 540ms/step - loss: 1.8078 - accuracy: 0.5002 - top_k_categorical_accuracy: 0.7803 - val_loss: 2.2024 - val_accuracy: 0.4224 - val_top_k_categorical_accuracy: 0.6987
# Epoch 14/50
# 707/707 [==============================] - ETA: 0s - loss: 1.7423 - accuracy: 0.5165 - top_k_categorical_accuracy: 0.7925
# Epoch 14: val_loss improved from 2.19421 to 2.15207, saving model to /content/drive/MyDrive/Colab_Notebooks/podcast/my_RNN_1layer:checkpoint.h5
# 707/707 [==============================] - 383s 541ms/step - loss: 1.7423 - accuracy: 0.5165 - top_k_categorical_accuracy: 0.7925 - val_loss: 2.1521 - val_accuracy: 0.4291 - val_top_k_categorical_accuracy: 0.7086
# Epoch 15/50
# 707/707 [==============================] - ETA: 0s - loss: 1.6794 - accuracy: 0.5295 - top_k_categorical_accuracy: 0.8058
# Epoch 15: val_loss improved from 2.15207 to 2.15069, saving model to /content/drive/MyDrive/Colab_Notebooks/podcast/my_RNN_1layer:checkpoint.h5
# 707/707 [==============================] - 383s 542ms/step - loss: 1.6794 - accuracy: 0.5295 - top_k_categorical_accuracy: 0.8058 - val_loss: 2.1507 - val_accuracy: 0.4371 - val_top_k_categorical_accuracy: 0.7122
# Epoch 16/50
# 707/707 [==============================] - ETA: 0s - loss: 1.6240 - accuracy: 0.5421 - top_k_categorical_accuracy: 0.8180
# Epoch 16: val_loss did not improve from 2.15069
# 707/707 [==============================] - 382s 541ms/step - loss: 1.6240 - accuracy: 0.5421 - top_k_categorical_accuracy: 0.8180 - val_loss: 2.1728 - val_accuracy: 0.4351 - val_top_k_categorical_accuracy: 0.7102
# Epoch 17/50
# 707/707 [==============================] - ETA: 0s - loss: 1.5622 - accuracy: 0.5583 - top_k_categorical_accuracy: 0.8295
# Epoch 17: val_loss did not improve from 2.15069
# 707/707 [==============================] - 382s 541ms/step - loss: 1.5622 - accuracy: 0.5583 - top_k_categorical_accuracy: 0.8295 - val_loss: 2.1734 - val_accuracy: 0.4328 - val_top_k_categorical_accuracy: 0.7111
# Epoch 18/50
# 707/707 [==============================] - ETA: 0s - loss: 1.5083 - accuracy: 0.5734 - top_k_categorical_accuracy: 0.8383
# Epoch 18: val_loss did not improve from 2.15069
# 707/707 [==============================] - 382s 540ms/step - loss: 1.5083 - accuracy: 0.5734 - top_k_categorical_accuracy: 0.8383 - val_loss: 2.2132 - val_accuracy: 0.4314 - val_top_k_categorical_accuracy: 0.7132
# Epoch 19/50
# 707/707 [==============================] - ETA: 0s - loss: 1.4595 - accuracy: 0.5886 - top_k_categorical_accuracy: 0.8481
# Epoch 19: val_loss did not improve from 2.15069
# 707/707 [==============================] - 382s 540ms/step - loss: 1.4595 - accuracy: 0.5886 - top_k_categorical_accuracy: 0.8481 - val_loss: 2.2423 - val_accuracy: 0.4280 - val_top_k_categorical_accuracy: 0.7102
# Epoch 20/50
# 707/707 [==============================] - ETA: 0s - loss: 1.4021 - accuracy: 0.5991 - top_k_categorical_accuracy: 0.8597
# Epoch 20: val_loss did not improve from 2.15069
# 707/707 [==============================] - 382s 541ms/step - loss: 1.4021 - accuracy: 0.5991 - top_k_categorical_accuracy: 0.8597 - val_loss: 2.2573 - val_accuracy: 0.4325 - val_top_k_categorical_accuracy: 0.7123
# Epoch 21/50
# 707/707 [==============================] - ETA: 0s - loss: 1.3510 - accuracy: 0.6149 - top_k_categorical_accuracy: 0.8673
# Epoch 21: val_loss did not improve from 2.15069
# 707/707 [==============================] - 382s 540ms/step - loss: 1.3510 - accuracy: 0.6149 - top_k_categorical_accuracy: 0.8673 - val_loss: 2.2684 - val_accuracy: 0.4365 - val_top_k_categorical_accuracy: 0.7150
# Epoch 22/50
# 707/707 [==============================] - ETA: 0s - loss: 1.2867 - accuracy: 0.6282 - top_k_categorical_accuracy: 0.8750
# Epoch 22: val_loss did not improve from 2.15069
# 707/707 [==============================] - 382s 540ms/step - loss: 1.2867 - accuracy: 0.6282 - top_k_categorical_accuracy: 0.8750 - val_loss: 2.3174 - val_accuracy: 0.4432 - val_top_k_categorical_accuracy: 0.7099
